# %%
# %load_ext autoreload
# %autoreload 2

import jCMIP as jc
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# %%
CMIP6list = '../CMIP6list'
jc.generateList('6',CMIP6list)

CMIP5list = '../CMIP5list'
jc.generateList('5',CMIP5list)
# Out:
# starting models on list: 0
# added ACCESS-CM2
# added ACCESS-ESM1-5
# added AWI-CM-1-1-HR
# added AWI-CM-1-1-LR
# added AWI-CM-1-1-MR
# added AWI-ESM-1-1-LR
# added BCC-CSM2-HR
# added BCC-CSM2-MR
# added BCC-ESM1
# added CAMS-CSM1-0
# added CAS-ESM2-0
# added CESM1-CAM5-SE-HR
# added CESM1-CAM5-SE-LR
# added CESM2
# added CESM2-FV2
# added CESM2-WACCM
# added CESM2-WACCM-FV2
# added CIESM
# added CMCC-CM2-HR4
# added CMCC-CM2-SR5
# added CMCC-CM2-VHR4
# added CMCC-ESM2
# added CNRM-CM6-1
# added CNRM-CM6-1-HR
# added CNRM-ESM2-1
# added CanESM5
# added CanESM5-CanOE
# added E3SM-1-0
# added E3SM-1-1
# added E3SM-1-1-ECA
# added EC-Earth3
# added EC-Earth3-AerChem
# added EC-Earth3-CC
# added EC-Earth3-LR
# added EC-Earth3-Veg
# added EC-Earth3-Veg-LR
# added EC-Earth3P
# added EC-Earth3P-HR
# added EC-Earth3P-VHR
# added ECMWF-IFS-HR
# added ECMWF-IFS-LR
# added ECMWF-IFS-MR
# added FGOALS-f3-H
# added FGOALS-f3-L
# added FGOALS-g3
# added FIO-ESM-2-0
# added GFDL-AM4
# ...

# %%
# Add save directory to all models (where masks and stuff are stored):
savedir = '/gws/pw/j05/wishbone/jmecki/'
jc.updateAllList(CMIP6list,savedir=(savedir + 'CMIP6/'))
jc.updateAllList(CMIP5list,savedir=(savedir + 'CMIP5/'))

# %%
# Add data directory to all models:
datadir5 = '/badc/cmip5/data/cmip5/output1/'
jc.updateAllList(CMIP5list,datadir=datadir5)
datadir6 = '/badc/cmip6/data/CMIP6/'
jc.updateAllList(CMIP6list,datadir=datadir6)

# %%
# Extra T points:

Clist = jc.readList(CMIP5list)
jc.updateList(CMIP5list,Model='HadCM3',    OextraT=True)
jc.updateList(CMIP5list,Model='HadGEM2-AO',OextraT=True)
jc.updateList(CMIP5list,Model='HadGEM2-CC',OextraT=True)
jc.updateList(CMIP5list,Model='HadGEM2-ES',OextraT=True)

Clist = jc.readList(CMIP6list)
jc.updateList(CMIP6list,Model='MRI-ESM2-0',OextraT=True)

# %%
# Flipped N-S:

Clist = jc.readList(CMIP5list)

Clist = jc.readList(CMIP6list)
jc.updateList(CMIP6list,Model='FGOALS-f3-L',    OflipNS=True)
jc.updateList(CMIP6list,Model='FGOALS-g3',      OflipNS=True)
jc.updateList(CMIP6list,Model='MPI-ESM-1-2-HAM',OflipNS=True)
jc.updateList(CMIP6list,Model='MPI-ESM1-2-HR',  OflipNS=True)
jc.updateList(CMIP6list,Model='MPI-ESM1-2-LR',  OflipNS=True)
jc.updateList(CMIP6list,Model='MPI-ESM1-2-XR',  OflipNS=True)

# %%
# Models without lon/lat properly defined:

Clist = jc.readList(CMIP5list)
jc.updateList(CMIP5list,Model='CFSv2-2011',  Ogrid='Unclear') # upside down?, grid unclear?, B-grid?
jc.updateList(CMIP5list,Model='CNRM-CM5',    Ogrid='Ctr')     # incorrect lon/lat on u and v points
jc.updateList(CMIP5list,Model='CNRM-CM5-2',  Ogrid='Ctr')     # incorrect lon/lat on u and v points
jc.updateList(CMIP5list,Model='EC-EARTH',    Ogrid='Unclear') # incorrect lon/lat on u and v points, no mask
jc.updateList(CMIP5list,Model='FGOALS-g2',   Ogrid='A')
jc.updateList(CMIP5list,Model='FGOALS-gl',   Ogrid='Btr')     # incorrect lon/lat on u and v points, upside down?
jc.updateList(CMIP5list,Model='FGOALS-s2',   Ogrid='Bbl')     # incorrect lon/lat on u and v points
jc.updateList(CMIP5list,Model='FIO-ESM',     Ogrid='Bbl')     # incorrect lon/lat on u and v points
jc.updateList(CMIP5list,Model='GEOS-5',      Ogrid='A')
jc.updateList(CMIP5list,Model='GISS-E2-H',   Ogrid='Unclear') # incorrect lon/lat on u and v points, grid unclear
jc.updateList(CMIP5list,Model='GISS-E2-H-CC',Ogrid='Unclear') # incorrect lon/lat on u and v points, grid unclear

Clist = jc.readList(CMIP6list)
jc.updateList(CMIP6list,Model='AWI-CM-1-1-MR', Ogrid='Unstructured')
jc.updateList(CMIP6list,Model='AWI-ESM-1-1-LR',Ogrid='Unstructured')
jc.updateList(CMIP6list,Model='CAS-ESM2-0',    Ogrid='Bbl')     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='CIESM',         Ogrid='Bbl')     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='CanESM5-CanOE', Ogrid='Unclear') # no uo/vo files
jc.updateList(CMIP6list,Model='EC-Earth3-LR',  Ogrid='Unclear') # no uo/vo files
jc.updateList(CMIP6list,Model='GFDL-CM4',      Ogrid='Cbl')     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='GFDL-ESM4',     Ogrid='Unclear') # no uo/vo files
jc.updateList(CMIP6list,Model='GFDL-OM4p5B',   Ogrid='Unclear') # no uo/vo files
jc.updateList(CMIP6list,Model='GISS-E2-1-H',   Ogrid='Unclear') # no uo/vo files
jc.updateList(CMIP6list,Model='GISS-E2-2-G',   Ogrid='Unclear') # no uo/vo files
jc.updateList(CMIP6list,Model='IITM-ESM',      Ogrid='Unclear') # no uo/vo files
jc.updateList(CMIP6list,Model='MRI-ESM2-0',    Ogrid='Btr')     # data not masked but NaNs, grid determined in mesh_mask computation
jc.updateList(CMIP6list,Model='NorCPM1',       Ogrid='Unclear') # no uo/vo files
jc.updateList(CMIP6list,Model='NorESM1-F',     Ogrid='Unclear') # no uo/vo files
jc.updateList(CMIP6list,Model='TaiESM1-TIMCOM',Ogrid='Unclear') # No thetao, and looks like maybe A grid?

# %%
# Models with periodic points:

Clist = jc.readList(CMIP5list)

Clist = jc.readList(CMIP6list)
jc.updateList(CMIP6list,Model='CMCC-CM2-HR4',     OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='CMCC-CM2-SR5',     OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='CMCC-CM2-VHR4',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='CMCC-ESM2',        OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='CNRM-CM6-1',       OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='CNRM-CM6-1-HR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='CNRM-ESM2-1',      OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3',        OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3-AerChem',OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3-CC',     OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3-Veg',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3-Veg-LR', OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3P',       OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3P-HR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='ECMWF-IFS-HR',     OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='ECMWF-IFS-LR',     OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='ECMWF-IFS-MR',     OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='IPSL-CM5A2-INCA',  OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='IPSL-CM6A-LR',     OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='IPSL-CM6A-LR-INCA',OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='MPI-ESM-1-2-HAM',  OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='MPI-ESM1-2-HR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='MPI-ESM1-2-LR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='MPI-ESM1-2-XR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='NESM3',            OextraWE=[1,1])  # remove halo points

# %%
# Models with mesh_mask computed:

Clist = jc.readList(CMIP5list)
Models = list(Clist.keys())
for mm in Models:
    Model = Clist[mm]
    mmfile = (Model.savedir + 'mesh_masks/' + Model.name + '_mesh_mask.nc')
    if os.path.exists(mmfile):
        jc.updateList(CMIP5list,Model=Model.name,Omeshmask=mmfile)

Clist = jc.readList(CMIP6list)
Models = list(Clist.keys())
for mm in Models:
    Model = Clist[mm]
    mmfile = (Model.savedir + 'mesh_masks/' + Model.name + '_mesh_mask.nc')
    if os.path.exists(mmfile):
        jc.updateList(CMIP6list,Model=Model.name,Omeshmask=mmfile)

# %%
# Determine lon/lat, regular and grid (Ocean):

filename = CMIP6list
Clist = jc.readList(filename)
Models = list(Clist.keys())

var  = 'thetao'
var2 = 'tos'

for mm in Models:
    # Check model data:
    Model = Clist[mm]
    print(mm)
    
    # Determine lon/lat:
    if Model.Olon == 'unknown':
        Files = Model.getFiles(var=var)
        nf = len(Files)
        print(nf)
        if (nf != 0):
            ncid = Dataset(Files[0],'r')
            klist = list(ncid.variables.keys())
            ncid.close()

            print(klist)
            
            for ll in range(0,len(klist)):
                if ((klist[ll] == 'lat') | (klist[ll] == 'latitude') | (klist[ll] == 'nav_lat')):
                    nlat = ll
                if ((klist[ll] == 'lon') | (klist[ll] == 'longitude') | (klist[ll] == 'nav_lon')):
                    nlon = ll

            jc.updateList(filename,Model.name,Olat=klist[nlat])
            jc.updateList(filename,Model.name,Olon=klist[nlon])

            ncid = Dataset(Files[0],'r')
            lon = ncid.variables[klist[nlon]][:]
            ncid.close()
            nd = np.squeeze((np.shape(np.shape(lon))))
            print(np.shape(lon))

            if nd == 2:
                jc.updateList(filename,Model.name,Oreg=False)
            elif nd == 1:
                jc.updateList(filename,Model.name,Oreg=True)
        else:
            Files = Model.getFiles(var=var2)
            nf = len(Files)
            print(nf)
            if (nf != 0):
                ncid = Dataset(Files[0],'r')
                klist = list(ncid.variables.keys())
                ncid.close()

                print(klist)

                for ll in range(0,len(klist)):
                    if ((klist[ll] == 'lat') | (klist[ll] == 'latitude') | (klist[ll] == 'nav_lat')):
                        nlat = ll
                    if ((klist[ll] == 'lon') | (klist[ll] == 'longitude') | (klist[ll] == 'nav_lon')):
                        nlon = ll

                jc.updateList(filename,Model.name,Olat=klist[nlat])
                jc.updateList(filename,Model.name,Olon=klist[nlon])

                ncid = Dataset(Files[0],'r')
                lon = ncid.variables[klist[nlon]][:]
                ncid.close()
                nd = np.squeeze((np.shape(np.shape(lon))))
                print(np.shape(lon))

                if nd == 2:
                    jc.updateList(filename,Model.name,Oreg=False)
                elif nd == 1:
                    jc.updateList(filename,Model.name,Oreg=True)

    Clist = jc.readList(filename)
    print(Clist[mm].Olon)
    print(Clist[mm].Olat)
    print(Clist[mm].Oreg)
    
    # Determine model grid:
    Model = Clist[mm]
    if ((Model.Ogrid == 'unknown')):
        # Find Files:
        so = Model.getFiles(var='so',EXP='*',ENS='*',vtype='Omon',gtype='gn')
        vo = Model.getFiles(var='vo',EXP='*',ENS='*',vtype='Omon',gtype='gn')
        uo = Model.getFiles(var='uo',EXP='*',ENS='*',vtype='Omon',gtype='gn')
    
        if ((len(so) != 0) & (len(vo) != 0) | (len(uo) != 0)):
            # Find mask, lat and lon:
            Tlon,Tlat = jc.Olatlon(Model,so[0],'so')
            Ulon,Ulat = jc.Olatlon(Model,uo[0],'uo')
            Vlon,Vlat = jc.Olatlon(Model,vo[0],'vo')
            
            if Model.Oreg:
                Tlon,Tlat = np.meshgrid(Tlon,Tlat)
                Vlon,Vlat = np.meshgrid(Vlon,Vlat)
                Ulon,Ulat = np.meshgrid(Ulon,Ulat)

            # Determine model grid:
            TmV_lat = Tlat[:,:]-Vlat[:,:]
            TmV_lon = Tlon[:,:]-Vlon[:,:]
            # -- => Btr
            # ++ => Bbl
            # -+ => Btl
            # -0 => Ct?
            # +0 => Cb?
            TmU_lat = Tlat[:,:]-Ulat[:,:]
            TmU_lon = Tlon[:,:]-Ulon[:,:]
            # -- => Btr
            # ++ => Bbl
            # -+ => Btl
            # 0- => C?r
            # 0+ => C?l
            VmU_lat = Vlat[:,:]-Ulat[:,:]
            VmU_lon = Vlon[:,:]-Ulon[:,:]
            # 00 => B
            # +- => Ctr
            # -- => Cbr
            # -+ => Cbl
            
            lims = 0.00001

            nn_TmV_lat = [np.sum(TmV_lat > lims), np.sum(np.abs(TmV_lat) <= lims), np.sum(TmV_lat < -lims)]
            nn_TmV_lon = [np.sum(TmV_lon > lims), np.sum(np.abs(TmV_lon) <= lims), np.sum(TmV_lon < -lims)]
            nn_TmU_lat = [np.sum(TmU_lat > lims), np.sum(np.abs(TmU_lat) <= lims), np.sum(TmU_lat < -lims)]
            nn_TmU_lon = [np.sum(TmU_lon > lims), np.sum(np.abs(TmU_lon) <= lims), np.sum(TmU_lon < -lims)]
            nn_VmU_lat = [np.sum(VmU_lat > lims), np.sum(np.abs(VmU_lat) <= lims), np.sum(VmU_lat < -lims)]
            nn_VmU_lon = [np.sum(VmU_lon > lims), np.sum(np.abs(VmU_lon) <= lims), np.sum(VmU_lon < -lims)]
            
            print('VmU lat: ' + str(nn_VmU_lat) + ', VmU lon: ' + str(nn_VmU_lon))
            print('TmU lat: ' + str(nn_TmU_lat) + ', TmU lon: ' + str(nn_TmU_lon))
            print('TmV lat: ' + str(nn_TmV_lat) + ', TmV lon: ' + str(nn_TmV_lon))
            
            if not (((np.argmax(nn_VmU_lat) == 1) & (np.argmax(nn_VmU_lon) == 1))):
                if ((np.argmax(nn_TmV_lat) == 2) & (np.argmax(nn_TmU_lon) == 2)):
                    grid = 'Ctr'   
                elif ((np.argmax(nn_TmV_lat) == 0) & (np.argmax(nn_TmU_lon) == 0)):
                    grid = 'Cbl'  
                elif ((np.argmax(nn_TmV_lat) == 2) & (np.argmax(nn_TmU_lon) == 0)):
                    grid = 'Ctl'
                elif ((np.argmax(nn_TmV_lat) == 0) & (np.argmax(nn_TmU_lon) == 2)):
                    grid = 'Cbr'
                else:
                    print('something has gone wrong')
            else:
                if ((np.argmax(nn_TmV_lat) == 2) & (np.argmax(nn_TmV_lon) == 2)):
                    grid = 'Btr'
                elif ((np.argmax(nn_TmV_lat) == 0) & (np.argmax(nn_TmV_lon) == 0)):
                    grid = 'Bbl'
                elif ((np.argmax(nn_TmV_lat) == 2) & (np.argmax(nn_TmV_lon) == 0)):
                    grid = 'Btl'
                elif ((np.argmax(nn_TmV_lat) == 0) & (np.argmax(nn_TmV_lon) == 2)):
                    grid = 'Bbr'
                else:
                    grid = 'unknown'
                    print('need to double check grid')
                    cmap = plt.get_cmap('seismic',21)

                    fig = plt.figure(figsize=(12,7))
                    plt.pcolormesh(TmV_lat,cmap=cmap,vmin=-1,vmax=1)
                    plt.title(Model.name + ', lat: T-V')
                    plt.colorbar()

                    fig = plt.figure(figsize=(12,7))
                    plt.pcolormesh(TmV_lon,cmap=cmap,vmin=-1,vmax=1)
                    plt.title(Model.name + ', lon: T-V')
                    plt.colorbar()

                    fig = plt.figure(figsize=(12,7))
                    plt.pcolormesh(TmU_lat,cmap=cmap,vmin=-1,vmax=1)
                    plt.title(Model.name + ', lat: T-U')
                    plt.colorbar()

                    fig = plt.figure(figsize=(12,7))
                    plt.pcolormesh(TmU_lon,cmap=cmap,vmin=-1,vmax=1)
                    plt.title(Model.name + ', lon: T-U')
                    plt.colorbar()

                    fig = plt.figure(figsize=(12,7))
                    plt.pcolormesh(VmU_lat,cmap=cmap,vmin=-1,vmax=1)
                    plt.title(Model.name + ', lat: V-U')
                    plt.colorbar()

                    fig = plt.figure(figsize=(12,7))
                    plt.pcolormesh(VmU_lon,cmap=cmap,vmin=-1,vmax=1)
                    plt.title(Model.name + ', lon: V-U')
                    plt.colorbar()

                    cmap = plt.get_cmap('seismic',3)

                    Tmask     = jc.Oread3Ddata(Model,so[0],var='so',time=0,mask=True)[0,:,:]
                    Umask     = jc.Oread3Ddata(Model,uo[0],var='uo',time=0,mask=True)[0,:,:]
                    Vmask     = jc.Oread3Ddata(Model,vo[0],var='vo',time=0,mask=True)[0,:,:]

                    fig = plt.figure(figsize=(12,7))
                    plt.pcolormesh(Tmask+Vmask,cmap=cmap,vmin=0,vmax=2)
                    plt.title(Model.name + ', mask: T+V')
                    plt.colorbar()

                    fig = plt.figure(figsize=(12,7))
                    plt.pcolormesh(Tmask+Umask,cmap=cmap,vmin=0,vmax=2)
                    plt.title(Model.name + ', mask: T+U')
                    plt.colorbar()

                    fig = plt.figure(figsize=(12,7))
                    plt.pcolormesh(Vmask+Umask,cmap=cmap,vmin=0,vmax=2)
                    plt.title(Model.name + ', mask: V+U')
                    plt.colorbar()

                    sys.exit()

            jc.updateList(filename,Model.name,Ogrid=grid)

    Clist = jc.readList(filename)
    print(Clist[mm].Ogrid)
# Out:
# ACCESS-CM2
# 294
# ['time', 'time_bnds', 'lev', 'lev_bnds', 'j', 'i', 'latitude', 'longitude', 'vertices_latitude', 'vertices_longitude', 'thetao']
# (300, 360)
# longitude
# latitude
# False
# VmU lat: [0, 108000, 0], VmU lon: [0, 108000, 0]
# TmU lat: [3460, 0, 104540], TmU lon: [3000, 0, 105000]
# TmV lat: [3460, 0, 104540], TmV lon: [3000, 0, 105000]
# Btr
# ACCESS-ESM1-5
# 472
# ['time', 'time_bnds', 'lev', 'lev_bnds', 'j', 'i', 'latitude', 'longitude', 'vertices_latitude', 'vertices_longitude', 'thetao']
# (300, 360)
# longitude
# latitude
# False
# VmU lat: [0, 108000, 0], VmU lon: [0, 108000, 0]
# TmU lat: [3460, 0, 104540], TmU lon: [3000, 0, 105000]
# TmV lat: [3460, 0, 104540], TmV lon: [3000, 0, 105000]
# Btr
# AWI-CM-1-1-HR
# 0
# 18
# ['time', 'lon', 'lon_bnds', 'lat', 'lat_bnds', 'tos']
# (1306775,)
# lon
# lat
# True
# unknown
# AWI-CM-1-1-LR
# 0
# 18
# ['time', 'lon', 'lon_bnds', 'lat', 'lat_bnds', 'tos']
# (126859,)
# lon
# lat
# True
# unknown
# AWI-CM-1-1-MR
# 370
# ...

# %%
# Determine lon/lat, regular and grid (Atmosphere):

filename = CMIP6list
Clist = jc.readList(filename)
Models = list(Clist.keys())

var  = 'tas'
var2 = 'psl'

for mm in Models:
    # Check model data:
    Model = Clist[mm]
    print(mm)
    
    # Determine lon/lat:
    if Model.Alon == 'unknown':
        Files = Model.getFiles(var=var)
        nf = len(Files)
        print(nf)
        if (nf != 0):
            ncid = Dataset(Files[0],'r')
            klist = list(ncid.variables.keys())
            ncid.close()

            print(klist)
            
            for ll in range(0,len(klist)):
                if ((klist[ll] == 'lat') | (klist[ll] == 'latitude') | (klist[ll] == 'nav_lat')):
                    nlat = ll
                if ((klist[ll] == 'lon') | (klist[ll] == 'longitude') | (klist[ll] == 'nav_lon')):
                    nlon = ll

            jc.updateList(filename,Model.name,Alat=klist[nlat])
            jc.updateList(filename,Model.name,Alon=klist[nlon])

            ncid = Dataset(Files[0],'r')
            lon = ncid.variables[klist[nlon]][:]
            ncid.close()
            nd = np.squeeze((np.shape(np.shape(lon))))
            print(np.shape(lon))

            if nd == 2:
                jc.updateList(filename,Model.name,Areg=False)
            elif nd == 1:
                jc.updateList(filename,Model.name,Areg=True)
        else:
            Files = Model.getFiles(var=var2)
            nf = len(Files)
            print(nf)
            if (nf != 0):
                ncid = Dataset(Files[0],'r')
                klist = list(ncid.variables.keys())
                ncid.close()

                print(klist)

                for ll in range(0,len(klist)):
                    if ((klist[ll] == 'lat') | (klist[ll] == 'latitude') | (klist[ll] == 'nav_lat')):
                        nlat = ll
                    if ((klist[ll] == 'lon') | (klist[ll] == 'longitude') | (klist[ll] == 'nav_lon')):
                        nlon = ll

                jc.updateList(filename,Model.name,Alat=klist[nlat])
                jc.updateList(filename,Model.name,Alon=klist[nlon])

                ncid = Dataset(Files[0],'r')
                lon = ncid.variables[klist[nlon]][:]
                ncid.close()
                nd = np.squeeze((np.shape(np.shape(lon))))
                print(np.shape(lon))

                if nd == 2:
                    jc.updateList(filename,Model.name,Areg=False)
                elif nd == 1:
                    jc.updateList(filename,Model.name,Areg=True)
            

    Clist = jc.readList(filename)
    print(Clist[mm].Alon)
    print(Clist[mm].Alat)
    print(Clist[mm].Areg)
# Out:
# ACCESS-CM2
# lon
# lat
# True
# ACCESS-ESM1-5
# lon
# lat
# True
# AWI-CM-1-1-HR
# 0
# 0
# unknown
# unknown
# True
# AWI-CM-1-1-LR
# 0
# 0
# unknown
# unknown
# True
# AWI-CM-1-1-MR
# lon
# lat
# True
# AWI-ESM-1-1-LR
# lon
# lat
# True
# BCC-CSM2-HR
# 0
# 0
# unknown
# unknown
# True
# BCC-CSM2-MR
# lon
# lat
# True
# BCC-ESM1
# lon
# lat
# True
# CAMS-CSM1-0
# lon
# lat
# True
# CAS-ESM2-0
# lon
# lat
# True
# CESM1-CAM5-SE-HR
# 0
# 0
# unknown
# unknown
# True
# CESM1-CAM5-SE-LR
# 0
# 0
# unknown
# unknown
# True
# CESM2
# lon
# lat
# True
# CESM2-FV2
# lon
# lat
# True
# CESM2-WACCM
# lon
# lat
# True
# CESM2-WACCM-FV2
# lon
# lat
# True
# CIESM
# 0
# 0
# unknown
# unknown
# True
# CMCC-CM2-HR4
# lon
# lat
# True
# CMCC-CM2-SR5
# lon
# lat
# True
# CMCC-CM2-VHR4
# lon
# lat
# True
# CMCC-ESM2
# lon
# lat
# True
# CNRM-CM6-1
# longitude
# latitude
# True
# CNRM-CM6-1-HR
# 0
# 0
# unknown
# unknown
# True
# CNRM-ESM2-1
# longitude
# latitude
# True
# CanESM5
# lon
# lat
# True
# ...
